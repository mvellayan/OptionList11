# %%
#! pip3 install SQLAlchemy
#! pip3 install pymysql
#! pip3 install mysqlclient

# %%
import pandas as pd
import pymysql

# import pandas.io.sql as psql
# import mysql.connector as connection
# import sqlalchemy as sql
# import _mysql

# %%
from sqlalchemy import create_engine

connect_string = 'mysql://rk_admin:rk2admin!@localhost/ol7'
engine = create_engine("mysql+pymysql://rk_admin:rk2admin!@localhost/ol7")
# sql_engine = sql.create_engine(connect_string)
query = "select * from option_list"
df = pd.read_sql_query(query, engine)
df
# Out:
#          con_id symbol      expiry  strike option_type  multiplier exchange  \
# 0     444905738   AAPL  2023-01-20   100.0           C         100    SMART
# 1     444905745   AAPL  2023-01-20   105.0           C         100    SMART
# 2     444905748   AAPL  2023-01-20   110.0           C         100    SMART
# 3     444905755   AAPL  2023-01-20   115.0           C         100    SMART
# 4     444905762   AAPL  2023-01-20   120.0           C         100    SMART
# ...         ...    ...         ...     ...         ...         ...      ...
# 6021  635083427   AAPL  2023-06-23   187.5           P         100    SMART
# 6022  635083473   AAPL  2023-06-23   192.5           P         100    SMART
# 6023  635083528   AAPL  2023-06-23   197.5           P         100    SMART
# 6024  635083607   AAPL  2023-06-23   202.5           P         100    SMART
# 6025  635083665   AAPL  2023-06-23   207.5           P         100    SMART
#
#               local_symbol
# 0     AAPL  230120C0010000
# 1     AAPL  230120C0010500
# 2     AAPL  230120C0011000
# 3     AAPL  230120C0011500
# 4     AAPL  230120C0012000
# ...                    ...
# 6021  AAPL  230623P0018750
# 6022  AAPL  230623P0019250
# 6023  AAPL  230623P0019750
# 6024  AAPL  230623P0020250
# 6025  AAPL  230623P0020750
#
# [6026 rows x 8 columns]

# %%
from sqlalchemy import text
conn = engine.connect()
x = conn.execute(text('call model_close(15);'))
y = conn.execute(text('call model_close(15);'))
